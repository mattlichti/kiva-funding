# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import clean

# %%
reload(clean)
# Out:
# <module 'clean' from '/home/matt/gdrive/final_project/Fundraising-Success/clean.py'>

# %%
lst = clean.import_loans('early')

# %%
df = clean.build_df(lst)

# %%
clean.dump(df,'early.json')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12500 entries, 396462 to 383504
# Data columns (total 20 columns):
# activity                    12500 non-null object
# bonus_credit_eligibility    12500 non-null bool
# description                 12500 non-null object
# image                       12500 non-null int64
# loan_amount                 12500 non-null int64
# name                        12500 non-null object
# partner_id                  12500 non-null int64
# posted_date                 12500 non-null datetime64[ns]
# sector                      12500 non-null object
# status                      12500 non-null object
# tags                        12500 non-null object
# themes                      912 non-null object
# use                         12500 non-null object
# country                     12500 non-null object
# repayment_interval          12500 non-null object
# repayment_term              12500 non-null int64
# ...

# %%
df = df.set_index('id')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12500 entries, 396462 to 383504
# Data columns (total 20 columns):
# activity                    12500 non-null object
# bonus_credit_eligibility    12500 non-null bool
# description                 12500 non-null object
# image                       12500 non-null int64
# loan_amount                 12500 non-null int64
# name                        12500 non-null object
# partner_id                  12500 non-null int64
# posted_date                 12500 non-null datetime64[ns]
# sector                      12500 non-null object
# status                      12500 non-null object
# tags                        12500 non-null object
# themes                      912 non-null object
# use                         12500 non-null object
# country                     12500 non-null object
# repayment_interval          12500 non-null object
# repayment_term              12500 non-null int64
# ...

# %%
df['days_available'] = ((df.planned_expiration_date - df.posted_date)/np.timedelta64(1, 'D')).round().astype(int)

# %%
df.drop('planned_expiration_date',axis=1)
# Out:
#                         activity bonus_credit_eligibility  \
# 0                      Livestock                    False
# 1      Personal Housing Expenses                    False
# 2                   Beauty Salon                     True
# 3                         Retail                     True
# 4                    Food Market                     True
# 5          Food Production/Sales                     True
# 6                        Farming                     True
# 7                         Sewing                     True
# 8                  General Store                     True
# 9                 Transportation                     True
# 10                      Services                    False
# 11                 Internet Cafe                     True
# 12     Personal Housing Expenses                    False
# 13                   Spare Parts                     True
# 14                       Farming                     True
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12500 entries, 0 to 12499
# Data columns (total 22 columns):
# activity                    12500 non-null object
# bonus_credit_eligibility    12500 non-null bool
# description                 12500 non-null object
# id                          12500 non-null int64
# image                       12500 non-null object
# loan_amount                 12500 non-null int64
# name                        12500 non-null object
# partner_id                  12500 non-null int64
# planned_expiration_date     12500 non-null datetime64[ns]
# posted_date                 12500 non-null datetime64[ns]
# sector                      12500 non-null object
# status                      12500 non-null object
# tags                        12500 non-null object
# themes                      912 non-null object
# use                         12500 non-null object
# country                     12500 non-null object
# ...

# %%
type(days_available[0])
# Out:
# numpy.int64

# %%
days_available.min()
# Out:
# 30

# %%
days_available.max()
# Out:
# 60

# %%
days_available.mean()
# Out:
# 30.698399999999999

# %%
np.timedelta64(1, 'D')
# Out:
# numpy.timedelta64(1,'D')

# %%
days_available[0]/np.timedelta64(1, 'D')
# Out:
# 30.0

# %%
df['image'] = df.image.map(lambda x: x['id'])

# %%
df.index = df.id

# %%
df.index
# Out:
# Int64Index([396462, 393591, 395423, 393556, 395417, 393565, 396478, 396480, 393594, 393592, 393596, 393598, 393599, 396487, 395402, 393601, 396643, 396512, 393602, 393605, 396649, 393608, 396654, 395403, 395404, 396482, 395405, 395406, 393610, 395425, 393196, 393629, 393614, 392537, 393622, 393612, 393199, 396043, 393631, 396655, 393630, 393627, 395433, 393609, 395437, 395439, 395426, 395428, 393641, 395438, 395429, 395445, 393100, 393623, 395448, 395451, 395468, 395430, 395467, 395469, 395432, 393645, 395474, 395478, 395463, 395480, 395484, 395486, 395487, 395476, 395465, 395482, 395489, 395492, 395493, 396054, 395702, 395704, 395497, 395529, 395625, 395690, 395709, 395696, 396058, 395705, 395686, 395688, 395708, 396061, 395683, 395673, 395675, 396658, 396071, 395685, 395726, 395727, 395734, 395719, ...], dtype='int64')

# %%
df.drop('id',axis=1)
# Out:
#                          activity bonus_credit_eligibility  \
# id
# 396462                  Livestock                    False
# 393591  Personal Housing Expenses                    False
# 395423               Beauty Salon                     True
# 393556                     Retail                     True
# 395417                Food Market                     True
# 393565      Food Production/Sales                     True
# 396478                    Farming                     True
# 396480                     Sewing                     True
# 393594              General Store                     True
# 393592             Transportation                     True
# 393596                   Services                    False
# 393598              Internet Cafe                     True
# 393599  Personal Housing Expenses                    False
# 396487                Spare Parts                     True
# 395402                    Farming                     True
# ...

# %%
df = df.set_index('id')

# %%
df
# Out:
#                           activity bonus_credit_eligibility  \
# image
# 1013609                  Livestock                    False
# 1008198  Personal Housing Expenses                    False
# 1010152               Beauty Salon                     True
# 1008137                     Retail                     True
# 726677                 Food Market                     True
# 1008145      Food Production/Sales                     True
# 1013637                    Farming                     True
# 1013640                     Sewing                     True
# 1008202              General Store                     True
# 1008200             Transportation                     True
# 1008209                   Services                    False
# 1008214              Internet Cafe                     True
# 1008217  Personal Housing Expenses                    False
# 1013657                Spare Parts                     True
# ...

# %%
a = clean.load_cleaned(['early'])

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 12500 entries, 364295.0 to 397594.0
# Data columns (total 20 columns):
# activity                    12500 non-null object
# bonus_credit_eligibility    12500 non-null bool
# country                     12500 non-null object
# currency_loss               12500 non-null object
# days_available              12500 non-null int64
# description                 12500 non-null object
# gender                      12500 non-null object
# group_size                  12500 non-null int64
# image                       12500 non-null int64
# loan_amount                 12500 non-null int64
# name                        12500 non-null object
# partner_id                  12500 non-null int64
# posted_date                 12500 non-null int64
# repayment_interval          12500 non-null object
# repayment_term              12500 non-null int64
# sector                      12500 non-null object
# ...

# %%
a.head()
# Out:
#                activity bonus_credit_eligibility country currency_loss  \
# 364295        Livestock                    False      AM          none
# 371188      Paper Sales                     True      JO        shared
# 371297  Vehicle Repairs                     True      LB          none
# 371352           Retail                     True      AM        shared
# 371370    General Store                     True      CO       partner
#
#         days_available                                        description  \
# 364295              60  Samvel lives in the Shirak region of Armenia i...
# 371188              60  Manal is now 24 years old and single. She live...
# 371297              60  Hussein is a 21-year-old Lebanese single man l...
# 371352              60  Suren is 53 years old. He lives in Vanadzor ci...
# 371370              60  With his Kiva loan Osvaldo bought articles and...
#
#        gender  group_size   image  loan_amount              name  partner_id  \
# ...

# %%
a.posted_date = a.posted_date / (1000.*60*60*24*365.25)-30

# %%
plt.scatter(a.posted_date, a.days_available)

# %%
df.groupby('status').count()
# Out:
#               activity  bonus_credit_eligibility  description  image  \
# status
# defaulted          211                       211          211    211
# expired            127                       127          127    127
# in_repayment        28                        28           28     28
# paid             12062                     12062        12062  12062
# refunded            72                        72           72     72
#
#               loan_amount   name  partner_id  posted_date  sector   tags  \
# status
# defaulted             211    211         211          211     211    211
# expired               127    127         127          127     127    127
# in_repayment           28     28          28           28      28     28
# paid                12062  12062       12062        12062   12062  12062
# refunded               72     72          72           72      72     72
#
#               themes    use  country  repayment_interval  repayment_term  \
# status
# ...

# %%
for n in xrange(13):
    print a.index[1000*n]
# Out:
# 364295.0
# 381810.0
# 384107.0
# 385238.0
# 386266.0
# 387281.0
# 388516.0
# 389712.0
# 390819.0
# 391931.0
# 393058.0
# 394402.0
# 395963.0

# %%
plt.scatter(a.posted_date.values, a.index)

# %%
clean.clean_and_dump('rand')

# %%
gg = clean.import_loans('rand')

# %%
clean.clean_and_dump('1500s')

# %%
new = clean.load_cleaned(['1500s'])

# %%
new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 50000 entries, 0.0 to 9999.0
# Data columns (total 21 columns):
# activity                    50000 non-null object
# bonus_credit_eligibility    50000 non-null bool
# country                     50000 non-null object
# currency_loss               50000 non-null object
# days_available              50000 non-null int64
# description                 49999 non-null object
# gender                      50000 non-null object
# group_size                  50000 non-null int64
# id                          50000 non-null int64
# image                       50000 non-null int64
# loan_amount                 50000 non-null int64
# name                        50000 non-null object
# partner_id                  50000 non-null int64
# posted_date                 50000 non-null int64
# repayment_interval          50000 non-null object
# repayment_term              50000 non-null int64
# sector                      50000 non-null object
# ...

# %%
new.groupby('status').count()
# Out:
#               activity  bonus_credit_eligibility  country  currency_loss  \
# status
# defaulted            7                         7        7              7
# expired           4015                      4015     4015           4015
# funded               7                         7        7              7
# in_repayment     42854                     42854    42854          42854
# paid              3063                      3063     3063           3063
# refunded            54                        54       54             54
#
#               days_available  description  gender  group_size     id  image  \
# status
# defaulted                  7            7       7           7      7      7
# expired                 4015         4015    4015        4015   4015   4015
# funded                     7            7       7           7      7      7
# in_repayment           42854        42854   42854       42854  42854  42854
# ...

# %%
a = pd.to_datetime(new.posted_date*10**6).values

# %%
a.max()
# Out:
# numpy.datetime64('2014-11-24T21:30:04.000000000-0800')

# %%
a.min()
# Out:
# numpy.datetime64('2014-08-09T07:10:06.000000000-0700')

# %%
plt.plot()
# Out:
# []

# %%
plt.scatter(new.posted_date,new.days_available)

# %%
a[0].
# Out:
# numpy.datetime64('2014-08-26T16:20:07.000000000-0700')

# %%
plt.plot(a)

# %%
a
# Out:
# array(['2014-08-26T16:20:07.000000000-0700',
#        '2014-08-26T16:20:07.000000000-0700',
#        '2014-08-26T16:50:01.000000000-0700', ...,
#        '2014-10-20T13:30:02.000000000-0700',
#        '2014-10-20T13:30:02.000000000-0700',
#        '2014-10-20T13:30:02.000000000-0700'], dtype='datetime64[ns]')

# %%
clean.clean_and_dump('early')

# %%
zz = clean.load_cleaned(['early'])

# %%
zz.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12500 entries, 396462 to 389396
# Data columns (total 20 columns):
# activity                    12500 non-null object
# bonus_credit_eligibility    12500 non-null bool
# country                     12500 non-null object
# currency_loss               12500 non-null object
# days_available              12500 non-null int64
# description                 12500 non-null object
# gender                      12500 non-null object
# group_size                  12500 non-null int64
# image                       12500 non-null int64
# loan_amount                 12500 non-null int64
# name                        12500 non-null object
# partner_id                  12500 non-null int64
# posted_date                 12500 non-null datetime64[ns]
# repayment_interval          12500 non-null object
# repayment_term              12500 non-null int64
# sector                      12500 non-null object
# ...

# %%
zz.posted_date.describe()
# Out:
# count                   12500
# unique                   6875
# first     2011-12-18 06:20:05
# last      2012-02-26 17:30:10
# top       2012-02-01 08:00:14
# freq                       18
# dtype: object

# %%
plt.plot(zz.posted_date)

# %%
zz.posted_date.min()
# Out:
# Timestamp('2011-12-18 06:20:05')

# %%
zz.posted_date.max()
# Out:
# Timestamp('2012-02-26 17:30:10')

# %%
clean.clean_and_dump('earlier')

# %%
hjk = clean.load_cleaned(['earlier'])

# %%
hjk
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-5787da2ff8f2> in <module>()
# ----> 1 hjk
#
# NameError: name 'hjk' is not defined
