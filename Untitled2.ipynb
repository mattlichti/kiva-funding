# %%
import clean
reload(clean)
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd

# %%
dfee = clean.load_cleaned(['earlier'])

# %%
dfee.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12999 entries, 375262 to 32943
# Data columns (total 20 columns):
# activity                    12999 non-null object
# bonus_credit_eligibility    12999 non-null bool
# country                     12999 non-null object
# currency_loss               12999 non-null object
# description                 12138 non-null object
# gender                      12999 non-null object
# group_size                  12999 non-null int64
# image                       12999 non-null int64
# loan_amount                 12999 non-null int64
# name                        12999 non-null object
# partner_id                  12999 non-null int64
# planned_expiration_date     683 non-null object
# posted_date                 12558 non-null object
# repayment_interval          12935 non-null object
# repayment_term              12933 non-null float64
# sector                      12999 non-null object
# status                      12999 non-null object
# ...

# %%
dfee.posted_date = pd.to_datetime(dfee.posted_date)

# %%
plt.scatter(df.index,df.posted_date)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-42f4b4c81f54> in <module>()
# ----> 1 plt.scatter(df.index,df.posted_date)
#
# /home/matt/anaconda/lib/python2.7/site-packages/matplotlib/pyplot.pyc in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, hold, **kwargs)
#    3192         ret = ax.scatter(x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    3193                          vmin=vmin, vmax=vmax, alpha=alpha,
# -> 3194                          linewidths=linewidths, verts=verts, **kwargs)
#    3195         draw_if_interactive()
#    3196     finally:
#
# /home/matt/anaconda/lib/python2.7/site-packages/matplotlib/axes/_axes.pyc in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, **kwargs)
#    3566             self.cla()
#    3567
# ...

# %%
noexpir = dfee[dfee.planned_expiration_date.isnull()]

# %%
noexpir.posted_date.max()
# Out:
# Timestamp('2012-01-24 18:30:04')

# %%
dfee.posted_date.max()
# Out:
# Timestamp('2012-01-24 18:30:04')

# %%
df = clean.load_cleaned(['early'])

# %%
df.posted_date.min()
# Out:
# Timestamp('2012-01-25 00:00:02')

# %%
df[df.posted_date < '2012-01-25'].shape
# Out:
# (967, 20)

# %%
df[df.posted_date > '2012-01-24T18:30:04Z'].shape
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-820ff6fe848a> in <module>()
# ----> 1 df[df.posted_date > '2012-01-24T18:30:04Z'].shape
#
# /home/matt/anaconda/lib/python2.7/site-packages/pandas/core/ops.pyc in wrapper(self, other)
#     570
#     571             # scalars
# --> 572             res = na_op(values, other)
#     573             if np.isscalar(res):
#     574                 raise TypeError('Could not compare %s type with Series'
#
# /home/matt/anaconda/lib/python2.7/site-packages/pandas/core/ops.pyc in na_op(x, y)
#     539                 result = getattr(x, name)(y)
#     540                 if result is NotImplemented:
# --> 541                     raise TypeError("invalid type comparison")
#     542             except (AttributeError):
#     543                 result = op(x, y)
#
# TypeError: invalid type comparison

# %%
df.posted_date.max()
# Out:
# Timestamp('2012-02-26 17:30:10')

# %%
df.posted_date.describe()
# Out:
# count                   12500
# unique                   6875
# first     2011-12-18 06:20:05
# last      2012-02-26 17:30:10
# top       2012-02-01 08:00:14
# freq                       18
# dtype: object

# %%
df = df[df.posted_date > '2012-01-25']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11533 entries, 396462 to 389396
# Data columns (total 20 columns):
# activity                    11533 non-null object
# bonus_credit_eligibility    11533 non-null bool
# country                     11533 non-null object
# currency_loss               11533 non-null object
# days_available              11533 non-null int64
# description                 11533 non-null object
# gender                      11533 non-null object
# group_size                  11533 non-null int64
# image                       11533 non-null int64
# loan_amount                 11533 non-null int64
# name                        11533 non-null object
# partner_id                  11533 non-null int64
# posted_date                 11533 non-null datetime64[ns]
# repayment_interval          11533 non-null object
# repayment_term              11533 non-null int64
# sector                      11533 non-null object
# ...

# %%
clean.clean_and_dump('1500s')

# %%
wdf = clean.load_cleaned(['early','1500s'])

# %%
wdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 61533 entries, 396462 to 784129
# Data columns (total 20 columns):
# activity                    61533 non-null object
# bonus_credit_eligibility    61533 non-null bool
# country                     61533 non-null object
# currency_loss               61533 non-null object
# days_available              61533 non-null int64
# description                 61532 non-null object
# gender                      61533 non-null object
# group_size                  61533 non-null int64
# image                       61533 non-null int64
# loan_amount                 61533 non-null int64
# name                        61533 non-null object
# partner_id                  61533 non-null int64
# posted_date                 61533 non-null datetime64[ns]
# repayment_interval          61533 non-null object
# repayment_term              61533 non-null int64
# sector                      61533 non-null object
# ...

# %%
wdf.posted_date.max()
# Out:
# Timestamp('2014-11-25 05:30:04')

# %%
wdf.groupby('status').count()
# Out:
#               activity  bonus_credit_eligibility  country  currency_loss  \
# status
# defaulted          204                       204      204            204
# expired           4126                      4126     4126           4126
# funded               7                         7        7              7
# in_repayment     42881                     42881    42881          42881
# paid             14191                     14191    14191          14191
# refunded           124                       124      124            124
#
#               days_available  description  gender  group_size  image  \
# status
# defaulted                204          204     204         204    204
# expired                 4126         4126    4126        4126   4126
# funded                     7            7       7           7      7
# in_repayment           42881        42881   42881       42881  42881
# paid                   14191        14191   14191       14191  14191
# ...

# %%
wdf.groupby('sector').count()
# Out:
#                 activity  bonus_credit_eligibility  country  currency_loss  \
# sector
# Agriculture        14899                     14899    14899          14899
# Arts                 934                       934      934            934
# Clothing            3349                      3349     3349           3349
# Construction         721                       721      721            721
# Education           2798                      2798     2798           2798
# Entertainment        103                       103      103            103
# Food               13638                     13638    13638          13638
# Health               498                       498      498            498
# Housing             3645                      3645     3645           3645
# Manufacturing        715                       715      715            715
# Personal Use        2129                      2129     2129           2129
# ...

# %%
wdf.groupby('activity').count()
# Out:
#                               bonus_credit_eligibility  country  \
# activity
# Agriculture                                       2380     2380
# Air Conditioning                                     4        4
# Animal Sales                                       947      947
# Arts                                                58       58
# Auto Repair                                        132      132
# Bakery                                             382      382
# Balut-Making                                         5        5
# Barber Shop                                         94       94
# Beauty Salon                                       609      609
# Bicycle Repair                                      25       25
# Bicycle Sales                                        6        6
# Blacksmith                                          48       48
# Bookbinding                                          2        2
# ...

# %%
wdf.groupby('country').count()
# Out:
#          activity  bonus_credit_eligibility  currency_loss  days_available  \
# country
# AL            133                       133            133             133
# AM            718                       718            718             718
# AZ            448                       448            448             448
# BF            150                       150            150             150
# BI            121                       121            121             121
# BJ            136                       136            136             136
# BO            913                       913            913             913
# BR             20                        20             20              20
# BZ             19                        19             19              19
# CD            225                       225            225             225
# CG             67                        67             67              67
# ...

# %%
len(wdf.description[394254])
# Out:
# 900

# %%
len(wdf.use[394254])
# Out:
# 63

# %%
ftn = clean.load_cleaned(['early'])

# %%
ftn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11533 entries, 396462 to 389396
# Data columns (total 20 columns):
# activity                    11533 non-null object
# bonus_credit_eligibility    11533 non-null bool
# country                     11533 non-null object
# currency_loss               11533 non-null object
# days_available              11533 non-null int64
# description                 11533 non-null object
# gender                      11533 non-null object
# group_size                  11533 non-null int64
# image                       11533 non-null int64
# loan_amount                 11533 non-null int64
# name                        11533 non-null object
# partner_id                  11533 non-null int64
# posted_date                 11533 non-null datetime64[ns]
# repayment_interval          11533 non-null object
# repayment_term              11533 non-null int64
# sector                      11533 non-null object
# ...

# %%
clean.dump(ftn,'description')

# %%
no_desc = clean.load_cleaned(['early'],['description'])

# %%
no_desc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11533 entries, 396462 to 389396
# Data columns (total 19 columns):
# activity                    11533 non-null object
# bonus_credit_eligibility    11533 non-null bool
# country                     11533 non-null object
# currency_loss               11533 non-null object
# days_available              11533 non-null int64
# gender                      11533 non-null object
# group_size                  11533 non-null int64
# image                       11533 non-null int64
# loan_amount                 11533 non-null int64
# name                        11533 non-null object
# partner_id                  11533 non-null int64
# posted_date                 11533 non-null datetime64[ns]
# repayment_interval          11533 non-null object
# repayment_term              11533 non-null int64
# sector                      11533 non-null object
# status                      11533 non-null object
# ...

# %%
clean.dump(no_desc,'no_description')

# %%
clean.clean_and_dump('1600s')

# %%
qdf = clean.load_cleaned(['1600s'],['description'])

# %%
qdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15301 entries, 804805 to 804144
# Data columns (total 19 columns):
# activity                    15301 non-null object
# bonus_credit_eligibility    15301 non-null bool
# country                     15301 non-null object
# currency_loss               15301 non-null object
# days_available              15301 non-null int64
# gender                      15301 non-null object
# group_size                  15301 non-null int64
# image                       15301 non-null int64
# loan_amount                 15301 non-null int64
# name                        15301 non-null object
# partner_id                  15301 non-null int64
# posted_date                 15301 non-null datetime64[ns]
# repayment_interval          15301 non-null object
# repayment_term              15301 non-null int64
# sector                      15301 non-null object
# status                      15301 non-null object
# ...

# %%
qdf.days_available.values.mean()
# Out:
# 39.326550250474064

# %%
qdf.posted_date.max()
# Out:
# Timestamp('2015-02-05 17:50:08')

# %%
qdf.groupby('status').count()
# Out:
#               activity  bonus_credit_eligibility  country  currency_loss  \
# status
# expired           1026                      1026     1026           1026
# funded             256                       256      256            256
# fundraising       5832                      5832     5832           5832
# in_repayment     27897                     27897    27897          27897
# paid               285                       285      285            285
# refunded            37                        37       37             37
#
#               days_available  gender  group_size  image  loan_amount   name  \
# status
# expired                 1026    1026        1026   1026         1026   1026
# funded                   256     256         256    256          256    256
# fundraising             5832    5832        5832   5832         5832   5832
# in_repayment           27897   27897       27897  27897        27897  27897
# ...

# %%
qdf[qdf.status=='fundraising']['posted_date'].min()
# Out:
# Timestamp('2014-12-22 18:00:07')

# %%
'2014-12-22'
# Out:
# '2014-12-22'

# %%
max_date = '2014-12-22'

# %%
qdf[qdf.posted_date < max_date].shape
# Out:
# (15301, 19)

# %%
qdf[qdf.posted_date > max_date].shape
# Out:
# (20032, 19)

# %%
qdf[qdf.status=='expired']['posted_date'].max()
# Out:
# Timestamp('2015-01-06 17:40:03')

# %%
min_date = '2014-12-15'

# %%
df = qdf

# %%
adf = df[((df.posted_date < max_date) and (df.posted_date > min_date))]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-b7608ece1454> in <module>()
# ----> 1 adf = df[((df.posted_date < max_date) and (df.posted_date > min_date))]
#
# /home/matt/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in __nonzero__(self)
#     690         raise ValueError("The truth value of a {0} is ambiguous. "
#     691                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# --> 692                          .format(self.__class__.__name__))
#     693
#     694     __bool__ = __nonzero__
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
adf
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15301 entries, 804805 to 804144
# Data columns (total 19 columns):
# activity                    15301 non-null object
# bonus_credit_eligibility    15301 non-null bool
# country                     15301 non-null object
# currency_loss               15301 non-null object
# days_available              15301 non-null int64
# gender                      15301 non-null object
# group_size                  15301 non-null int64
# image                       15301 non-null int64
# loan_amount                 15301 non-null int64
# name                        15301 non-null object
# partner_id                  15301 non-null int64
# posted_date                 15301 non-null datetime64[ns]
# repayment_interval          15301 non-null object
# repayment_term              15301 non-null int64
# sector                      15301 non-null object
# status                      15301 non-null object
# ...

# %%
clean.clean_and_dump(['700s', '1600s'])
