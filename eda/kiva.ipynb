# %%
import pandas as pd
import json

# %%
a = open('borrowers/1553.json')

# %%
for line in a:
    z = json.loads(line)

# %%
z.keys()
# Out:
# [u'header', u'loans']

# %%
z['header']
# Out:
# {u'date': u'2014-12-25T18:39:04Z',
#  u'page': 1553,
#  u'page_size': 500,
#  u'total': 818748}

# %%
loans = z['loans']

# %%
len(loans)
# Out:
# 500

# %%
type(loans[0])
# Out:
# dict

# %%
loans[0].keys()
# Out:
# [u'funded_amount',
#  u'sector',
#  u'posted_date',
#  u'basket_amount',
#  u'image',
#  u'bonus_credit_eligibility',
#  u'video',
#  u'planned_expiration_date',
#  u'partner_id',
#  u'id',
#  u'use',
#  u'delinquent',
#  u'paid_amount',
#  u'theme',
#  u'location',
#  u'status',
#  u'terms',
#  u'description',
#  u'tags',
#  u'journal_totals',
#  u'translator',
#  u'loan_amount',
#  u'funded_date',
#  u'name',
#  u'borrowers',
#  u'lender_count',
#  u'currency_exchange_loss_amount',
#  u'paid_date',
#  u'payments',
#  u'activity']

# %%
len(loans[444])
# Out:
# 30

# %%
aa = pd.DataFrame(loans)

# %%
aa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500 entries, 0 to 499
# Data columns (total 30 columns):
# activity                         500 non-null object
# basket_amount                    0 non-null object
# bonus_credit_eligibility         500 non-null bool
# borrowers                        500 non-null object
# currency_exchange_loss_amount    3 non-null float64
# delinquent                       3 non-null object
# description                      500 non-null object
# funded_amount                    500 non-null int64
# funded_date                      485 non-null object
# id                               500 non-null int64
# image                            500 non-null object
# journal_totals                   500 non-null object
# lender_count                     500 non-null int64
# loan_amount                      500 non-null int64
# location                         500 non-null object
# name                             500 non-null object
# ...

# %%
aa.funded_date
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-26b16e44a26c> in <module>()
# ----> 1 aa.funded_date
#
# NameError: name 'aa' is not defined

# %%
aa.iloc[490]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-87686ae88339> in <module>()
# ----> 1 aa.iloc[490]
#
# NameError: name 'aa' is not defined

# %%
aa['status'].unique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-febdeeb92428> in <module>()
# ----> 1 aa['status'].unique()
#
# NameError: name 'aa' is not defined

# %% [markdown]
# ## aa.activity.unique()

# %%
b = open('borrowers/1262.json')

# %%
dic = json.loads(b.readline())

# %%
dic.keys()
# Out:
# [u'header', u'loans']

# %%
df = pd.DataFrame(dic['loans'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500 entries, 0 to 499
# Data columns (total 30 columns):
# activity                         500 non-null object
# basket_amount                    0 non-null object
# bonus_credit_eligibility         500 non-null bool
# borrowers                        500 non-null object
# currency_exchange_loss_amount    56 non-null float64
# delinquent                       49 non-null object
# description                      500 non-null object
# funded_amount                    500 non-null int64
# funded_date                      500 non-null object
# id                               500 non-null int64
# image                            500 non-null object
# journal_totals                   500 non-null object
# lender_count                     500 non-null int64
# loan_amount                      500 non-null int64
# location                         500 non-null object
# name                             500 non-null object
# ...

# %%
df.groupby('status').count()
# Out:
#               activity  basket_amount  bonus_credit_eligibility  borrowers  \
# status
# defaulted            1              1                         1          1
# in_repayment       136            136                       136        136
# paid               362            362                       362        362
# refunded             1              1                         1          1
#
#               currency_exchange_loss_amount  delinquent  description  \
# status
# defaulted                                 0           1            1
# in_repayment                             34         136          136
# paid                                     22         362          362
# refunded                                  0           1            1
#
#               funded_amount  funded_date   id ...   payments  \
# status                                        ...
# defaulted                 1            1    1 ...          1
# ...

# %%
df.groupby('activity').count()
# Out:
#                                 basket_amount  bonus_credit_eligibility  \
# activity
# Agriculture                                76                        76
# Air Conditioning                            1                         1
# Animal Sales                                4                         4
# Bakery                                      3                         3
# Barber Shop                                 3                         3
# Beauty Salon                                2                         2
# Butcher Shop                                1                         1
# Cafe                                        1                         1
# Cattle                                      2                         2
# Cereals                                     1                         1
# Charcoal Sales                              6                         6
# Cloth & Dressmaking Supplies                1                         1
# ...

# %%
df.groupby('sector').count()
# Out:
#                 activity  basket_amount  bonus_credit_eligibility  borrowers  \
# sector
# Agriculture          177            177                       177        177
# Arts                  13             13                        13         13
# Clothing              34             34                        34         34
# Construction           7              7                         7          7
# Education             26             26                        26         26
# Food                  93             93                        93         93
# Health                 7              7                         7          7
# Housing               27             27                        27         27
# Manufacturing          1              1                         1          1
# Personal Use           3              3                         3          3
# Retail                66             66                        66         66
# ...

# %%
df.paid_date
# Out:
# 0     2014-08-22T09:24:32Z
# 1     2014-11-17T16:00:54Z
# 2                     None
# 3                     None
# 4                     None
# 5     2014-11-20T10:21:04Z
# 6     2014-10-17T18:51:27Z
# 7     2014-10-17T18:51:27Z
# 8                     None
# 9     2014-10-20T09:42:49Z
# 10    2014-12-25T10:50:01Z
# 11    2014-06-17T19:51:47Z
# 12                    None
# 13                    None
# 14    2014-08-22T09:24:32Z
# ...
# 485    2014-12-17T13:46:57Z
# 486    2014-09-17T14:45:29Z
# 487                    None
# 488                    None
# 489                    None
# 490    2014-08-17T14:49:45Z
# 491    2014-08-17T14:49:45Z
# 492    2014-08-17T14:49:45Z
# 493                    None
# 494                    None
# 495    2014-08-17T14:40:07Z
# 496                    None
# 497    2014-05-17T14:28:18Z
# 498    2014-02-26T09:48:10Z
# 499    2014-08-17T14:49:45Z
# Name: paid_date, Length: 500, dtype: object

# %%
aa.groupby('status').count()
# Out:
#               activity  basket_amount  bonus_credit_eligibility  borrowers  \
# status
# expired             15             15                        15         15
# in_repayment       483            483                       483        483
# paid                 2              2                         2          2
#
#               currency_exchange_loss_amount  delinquent  description  \
# status
# expired                                   0          15           15
# in_repayment                              3         483          483
# paid                                      0           2            2
#
#               funded_amount  funded_date   id ...   payments  \
# status                                        ...
# expired                  15           15   15 ...         15
# in_repayment            483          483  483 ...        483
# paid                      2            2    2 ...          2
#
# ...

# %%
df.payments[0]
# Out:
# [{u'amount': 5.06,
#   u'comment': None,
#   u'currency_exchange_loss_amount': 0,
#   u'local_amount': 405,
#   u'payment_id': 429436895,
#   u'processed_date': u'2013-11-01T07:00:00Z',
#   u'rounded_local_amount': 409.96,
#   u'settlement_date': u'2013-12-17T11:27:34Z'},
#  {u'amount': 2.57,
#   u'comment': None,
#   u'currency_exchange_loss_amount': 0,
#   u'local_amount': 205,
#   u'payment_id': 429436896,
#   u'processed_date': u'2013-11-08T08:00:00Z',
#   u'rounded_local_amount': 207.51,
#   u'settlement_date': u'2013-12-17T11:36:14Z'},
#  {u'amount': 2.62,
#   u'comment': None,
#   u'currency_exchange_loss_amount': 0,
#   u'local_amount': 210,
#   u'payment_id': 429436897,
#   u'processed_date': u'2013-11-15T08:00:00Z',
#   u'rounded_local_amount': 212.57,
#   u'settlement_date': u'2013-12-17T11:44:50Z'},
#  {u'amount': 2.63,
#   u'comment': None,
#   u'currency_exchange_loss_amount': 0,
#   u'local_amount': 210,
#   u'payment_id': 429436898,
# ...

# %%
fp = open('field_partners.json')

# %%
fp = json.loads(fp.readline())

# %%
type(fp)
# Out:
# dict

# %%
fp.keys()
# Out:
# [u'partners', u'paging']

# %%
type(fp['partners'])
# Out:
# list

# %%
pdf = pd.DataFrame(fp['partners'])

# %%
pdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 368 entries, 0 to 367
# Data columns (total 22 columns):
# average_loan_size_percent_per_capita_income    368 non-null float64
# charges_fees_and_interest                      368 non-null bool
# countries                                      368 non-null object
# currency_exchange_loss_rate                    368 non-null float64
# default_rate                                   368 non-null object
# default_rate_note                              368 non-null object
# delinquency_rate                               368 non-null object
# delinquency_rate_note                          368 non-null object
# id                                             368 non-null int64
# image                                          362 non-null object
# loans_at_risk_rate                             368 non-null float64
# loans_posted                                   368 non-null int64
# ...

# %%
pdf.social_performance_strengths
# Out:
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 8     [{u'description': u'These Field Partners use f...
# 9                                                   NaN
# 10                                                  NaN
# 11                                                  NaN
# 12    [{u'description': u'The work of most microfina...
# 13                                                  NaN
# 14                                                  NaN
# ...
# 353    [{u'description': u'These Field Partners provi...
# 354    [{u'description': u'These Field Partners provi...
# ...

# %%
aa.image
# Out:
# 0     {u'id': 1702466, u'template_id': 1}
# 1     {u'id': 1702468, u'template_id': 1}
# 2     {u'id': 1702475, u'template_id': 1}
# 3     {u'id': 1702478, u'template_id': 1}
# 4     {u'id': 1702492, u'template_id': 1}
# 5     {u'id': 1702493, u'template_id': 1}
# 6     {u'id': 1702494, u'template_id': 1}
# 7     {u'id': 1699765, u'template_id': 1}
# 8     {u'id': 1701533, u'template_id': 1}
# 9     {u'id': 1699932, u'template_id': 1}
# 10    {u'id': 1699935, u'template_id': 1}
# 11    {u'id': 1702441, u'template_id': 1}
# 12    {u'id': 1702469, u'template_id': 1}
# 13    {u'id': 1702472, u'template_id': 1}
# 14    {u'id': 1702495, u'template_id': 1}
# ...
# 485    {u'id': 1699740, u'template_id': 1}
# 486    {u'id': 1699735, u'template_id': 1}
# 487    {u'id': 1699762, u'template_id': 1}
# 488    {u'id': 1699769, u'template_id': 1}
# 489    {u'id': 1700259, u'template_id': 1}
# 490    {u'id': 1700261, u'template_id': 1}
# 491    {u'id': 1699963, u'template_id': 1}
# ...
