# %%
import clean
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
reload(clean)
# Out:
# <module 'clean' from '/home/matt/gdrive/final_project/Fundraising-Success/clean.py'>

# %%
lst = clean.import_loans('early')

# %%
df = clean.build_df(lst)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12500 entries, 0 to 12499
# Data columns (total 21 columns):
# activity                    12500 non-null object
# bonus_credit_eligibility    12500 non-null bool
# description                 12500 non-null object
# id                          12500 non-null int64
# image                       12500 non-null object
# loan_amount                 12500 non-null int64
# name                        12500 non-null object
# partner_id                  12500 non-null int64
# planned_expiration_date     12500 non-null datetime64[ns]
# posted_date                 12500 non-null datetime64[ns]
# sector                      12500 non-null object
# status                      12500 non-null object
# tags                        12500 non-null object
# themes                      912 non-null object
# use                         12500 non-null object
# country                     12500 non-null object
# ...

# %%
clean.dump(df)

# %%
clean.get_start_date(df)
# Out:
# nan

# %%
df.posted_date
# Out:
# 0     2012-01-01T09:30:24Z
# 1     2012-01-01T09:30:25Z
# 2     2012-01-01T09:30:25Z
# 3     2012-01-01T09:30:25Z
# 4     2012-01-01T09:30:25Z
# 5     2012-01-01T09:30:25Z
# 6     2011-12-02T14:20:04Z
# 7     2011-12-02T14:30:03Z
# 8     2012-01-01T15:30:04Z
# 9     2012-01-01T20:30:06Z
# 10    2012-01-01T22:30:07Z
# 11    2012-01-01T23:00:07Z
# 12    2012-01-02T03:00:06Z
# 13    2012-01-02T05:20:05Z
# 14    2012-01-02T06:40:08Z
# ...
# 6984    2012-02-01T08:01:35Z
# 6985    2012-02-01T08:01:35Z
# 6986    2012-02-01T08:01:36Z
# 6987    2012-02-01T08:01:36Z
# 6988    2012-02-01T08:01:36Z
# 6989    2012-02-01T08:01:36Z
# 6990    2012-02-01T08:01:36Z
# 6991    2012-02-01T08:01:36Z
# 6992    2012-02-01T08:01:36Z
# 6993    2012-02-01T08:01:36Z
# 6994    2012-02-01T08:01:36Z
# 6995    2012-02-01T08:01:36Z
# 6996    2012-02-01T08:01:36Z
# 6997    2012-02-01T08:01:36Z
# 6998    2012-02-01T08:01:36Z
# Name: posted_date, Length: 6999, dtype: object

# %%
post = pd.to_datetime(df.posted_date)

# %%
df['posted_date'] = pd.to_datetime(df.posted_date)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6999 entries, 0 to 6998
# Data columns (total 21 columns):
# activity                    6999 non-null object
# bonus_credit_eligibility    6999 non-null bool
# description                 6849 non-null object
# id                          6999 non-null int64
# image                       6999 non-null object
# loan_amount                 6999 non-null int64
# name                        6999 non-null object
# partner_id                  6999 non-null int64
# planned_expiration_date     4683 non-null object
# posted_date                 6928 non-null datetime64[ns]
# sector                      6999 non-null object
# status                      6999 non-null object
# tags                        6999 non-null object
# themes                      404 non-null object
# use                         6999 non-null object
# country                     6999 non-null object
# repayment_interval          6992 non-null object
# ...

# %%
df.sort('posted_date')[2200:2500]
# Out:
#                             activity bonus_credit_eligibility  \
# 5561                         Farming                     True
# 5654                         Vehicle                     True
# 5747                         Fishing                     True
# 565                   Clothing Sales                    False
# 5843                     Agriculture                     True
# 1531                            Pigs                     True
# 93                         Carpentry                     True
# 94                              Cafe                     True
# 1625  Primary/secondary school costs                     True
# 842                  Cosmetics Sales                    False
# 95                           Farming                    False
# 1811                Furniture Making                     True
# 96                       Spare Parts                     True
# 97                    Transportation                    False
# ...

# %%
expir = df[df.planned_expiration_date.notnull()]

# %%
expir.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4683 entries, 0 to 6998
# Data columns (total 21 columns):
# activity                    4683 non-null object
# bonus_credit_eligibility    4683 non-null bool
# description                 4683 non-null object
# id                          4683 non-null int64
# image                       4683 non-null object
# loan_amount                 4683 non-null int64
# name                        4683 non-null object
# partner_id                  4683 non-null int64
# planned_expiration_date     4683 non-null object
# posted_date                 4683 non-null datetime64[ns]
# sector                      4683 non-null object
# status                      4683 non-null object
# tags                        4683 non-null object
# themes                      331 non-null object
# use                         4683 non-null object
# country                     4683 non-null object
# repayment_interval          4683 non-null object
# ...

# %%
expir.sort('posted_date')
# Out:
#                        activity bonus_credit_eligibility  \
# 394                  Shoe Sales                     True
# 403               Mobile Phones                     True
# 409                 Barber Shop                     True
# 410                        Taxi                     True
# 417         Fruits & Vegetables                     True
# 423                        Taxi                     True
# 427                        Taxi                    False
# 6316                   Clothing                     True
# 6317             Consumer Goods                    False
# 6318                       Taxi                    False
# 6319                       Taxi                    False
# 6320                     Retail                     True
# 6321                       Taxi                     True
# 6322                       Taxi                    False
# 6323            Cosmetics Sales                    False
# ...

# %%
no_expir = df[df.planned_expiration_date.isnull()]

# %%
no_expir.sort('posted_date',ascending=False)
# Out:
#                           activity bonus_credit_eligibility  \
# 2191           Home Products Sales                     True
# 2286                   Agriculture                     True
# 1910                   Agriculture                     True
# 6315                 General Store                     True
# 2098                 Used Clothing                     True
# 660                           Food                    False
# 5750                        Sewing                     True
# 6220                       Cereals                    False
# 6034            Personal Purchases                     True
# 938                  Grocery Store                     True
# 5846                 General Store                     True
# 5657                    Embroidery                     True
# 845          Food Production/Sales                    False
# 2377                    Restaurant                     True
# 2285                  Beauty Salon                     True
# ...

# %%
expir.sort('posted_date',ascending=False)
# Out:
#                        activity bonus_credit_eligibility  \
# 6998                Electrician                    False
# 6992                    Farming                    False
# 6986                     Cattle                    False
# 6987        Fruits & Vegetables                     True
# 6988                     Cattle                    False
# 6989              General Store                     True
# 6991              General Store                     True
# 6990                Food Market                     True
# 6993                  Livestock                    False
# 6994                     Cattle                    False
# 6995                     Cattle                    False
# 6996                     Cattle                    False
# 6997                    Farming                     True
# 6980                Soft Drinks                     True
# 6974                    Farming                     True
# ...

# %%
last = no_expir.posted_date.max()

# %%
df[df.planned_expiration_date.isnull()].posted_date.max()
# Out:
# Timestamp('2012-01-24 18:30:04')

# %%
expir.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4683 entries, 0 to 6998
# Data columns (total 21 columns):
# activity                    4683 non-null object
# bonus_credit_eligibility    4683 non-null bool
# description                 4683 non-null object
# id                          4683 non-null int64
# image                       4683 non-null object
# loan_amount                 4683 non-null int64
# name                        4683 non-null object
# partner_id                  4683 non-null int64
# planned_expiration_date     4683 non-null object
# posted_date                 4683 non-null datetime64[ns]
# sector                      4683 non-null object
# status                      4683 non-null object
# tags                        4683 non-null object
# themes                      331 non-null object
# use                         4683 non-null object
# country                     4683 non-null object
# repayment_interval          4683 non-null object
# ...

# %%
expir[expir.posted_date > last].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3144 entries, 2500 to 6998
# Data columns (total 21 columns):
# activity                    3144 non-null object
# bonus_credit_eligibility    3144 non-null bool
# description                 3144 non-null object
# id                          3144 non-null int64
# image                       3144 non-null object
# loan_amount                 3144 non-null int64
# name                        3144 non-null object
# partner_id                  3144 non-null int64
# planned_expiration_date     3144 non-null object
# posted_date                 3144 non-null datetime64[ns]
# sector                      3144 non-null object
# status                      3144 non-null object
# tags                        3144 non-null object
# themes                      289 non-null object
# use                         3144 non-null object
# country                     3144 non-null object
# repayment_interval          3144 non-null object
# ...

# %%
expir[expir.posted_date > last].head()
# Out:
#                           activity bonus_credit_eligibility  \
# 2500         Food Production/Sales                     True
# 2501  Cloth & Dressmaking Supplies                    False
# 2502                        Retail                    False
# 2503                    Milk Sales                     True
# 2504                        Retail                    False
#
#                                             description      id  \
# 2500  Nenita is from San Carlos, Tukuran, Zamboanga ...  387238
# 2501  The borrower is a married woman and the mother...  387015
# 2502  Siny is a 27-year old woman who is divorced an...  387021
# 2503  Mrs. Munkhtuya, 25, sells diary products, such...  387240
# 2504  Sope Mohamed Group is made up of five women wh...  387023
#
#                                    image  loan_amount                name  \
# 2500  {u'id': 996841, u'template_id': 1}          250              Nenita
# ...

# %%
last
# Out:
# Timestamp('2012-01-24 18:30:04')

# %%
df.id
# Out:
# 0     375262
# 1     376031
# 2     376053
# 3     376534
# 4     376041
# 5     376013
# 6     365201
# 7     365203
# 8     375033
# 9     376801
# 10    376238
# 11    376841
# 12    376776
# 13    376408
# 14    377316
# ...
# 6984    383405
# 6985    383408
# 6986    383522
# 6987    383538
# 6988    383539
# 6989    383571
# 6990    383510
# 6991    383574
# 6992    383512
# 6993    383498
# 6994    383546
# 6995    383467
# 6996    383534
# 6997    383456
# 6998    383504
# Name: id, Length: 6999, dtype: int64

# %%
plt.scatter(df.id,df.posted_date)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-68-b4d4b4e8bba7> in <module>()
# ----> 1 plt.scatter(df.id,df.posted_date)
#
# /home/matt/anaconda/lib/python2.7/site-packages/matplotlib/pyplot.pyc in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, hold, **kwargs)
#    3192         ret = ax.scatter(x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    3193                          vmin=vmin, vmax=vmax, alpha=alpha,
# -> 3194                          linewidths=linewidths, verts=verts, **kwargs)
#    3195         draw_if_interactive()
#    3196     finally:
#
# /home/matt/anaconda/lib/python2.7/site-packages/matplotlib/axes/_axes.pyc in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, **kwargs)
#    3621             edgecolors = 'face'
#    3622
# -> 3623         offsets = np.dstack((x, y))
# ...

# %%
df.posted_date.describe()
# Out:
# count                    6928
# unique                   4776
# first     2006-11-07 04:23:26
# last      2012-02-01 08:01:36
# top       2012-02-01 08:00:14
# freq                       18
# dtype: object

# %%
bla = df[df.posted_date.notnull()]['posted_date'].astype(int)/(10**9*60*60*24*365)-30

# %%
x = df[df.posted_date.notnull()]['id']

# %%
bla.max()
# Out:
# 12.182819951801115

# %%
plt.scatter(x,bla)

# %%
plt.plot(bla)

# %%
plt.plot(bla[13900:15000])

# %%
bla[13950:15000]
# Out:
# 13992    12.139422
# 13993    12.139422
# 13994    12.139441
# 13995    12.139441
# 13996    12.139441
# 13997    12.139441
# 13998    12.139441
# 13999    12.139460
# 14000     9.486492
# 14001     9.532040
# 14002     9.583124
# 14003     9.693950
# 14004     9.681602
# 14005     9.776143
# 14006     9.772223
# ...
# 15056    12.113243
# 15057    12.113243
# 15058    12.113243
# 15059    12.113243
# 15060    12.113243
# 15061    12.113243
# 15062    12.113243
# 15063    12.113243
# 15064    12.113243
# 15065    12.113243
# 15066    12.113243
# 15067    12.113243
# 15068    12.113243
# 15069    12.113243
# 15070    12.113243
# Name: posted_date, Length: 1050, dtype: float64

# %%
df.posted_date.min()
# Out:
# Timestamp('2011-12-18 06:20:05')
